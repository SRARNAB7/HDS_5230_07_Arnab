# %% [markdown]
# <a href="https://colab.research.google.com/github/SRARNAB7/HDS_5230_07_Arnab/blob/main/Practice_Interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
condemns= pd.read_csv('https://hds5210-data.s3.amazonaws.com/condemn.txt', low_memory = False)

# %%
condemns.columns
# Out:
# Index(['AcctNum', 'PrclErr', 'AddrAdjusted', 'CityBlock', 'Parcel',
#        'OwnerCode', 'Handle', 'Parcel9', 'AddrNum', 'AddrSuf', 'StDir',
#        'StName', 'StType', 'InspectDate', 'InspectType', 'CondLetterSent',
#        'Status', 'OwnerCompany', 'OwnerName', 'OwnerAddr', 'OwnerCity',
#        'OwnerState', 'OwnerZIP', 'GeoCityBLockPart', 'Ward00', 'Precinct02',
#        'Nbrhd', 'CDADist', 'CDASubDist', 'PoliceDist', 'CensBlock00',
#        'AsrNbrhd', 'ImpactCode', 'NLC', 'Parity', 'Inspector', 'Images',
#        'FirstDate', 'LastDate', 'UpDateGeo'],
#       dtype='object')

# %%
condemns.head()
# Out:
#    AcctNum  PrclErr AddrAdjusted  CityBlock  Parcel  OwnerCode        Handle  \
# 0      1.0      0.0        False    3652.00   341.0        1.0  1.365200e+10
# 1      2.0      0.0        False     666.00    80.0        0.0  1.066600e+10
# 2      3.0      0.0        False    3913.01   120.0        1.0  1.391301e+10
# 3      4.0      2.0        False    3744.00   145.0        0.0  1.374400e+10
# 4      5.0      0.0        False    1103.00    30.0        0.0  1.110300e+10
#
#        Parcel9 AddrNum AddrSuf  ... CensBlock00 AsrNbrhd ImpactCode    NLC  \
# 0  365200341.0    4049          ...   1114.4006    309.0        0.0  123.0
# 1   66600080.0     906          ...   1234.2003    248.0        0.0  104.0
# 2  391301120.0    4218          ...   1191.1004    230.0        0.0  210.0
# 3  374400145.0    4145          ...   1111.4000    231.0        0.0   92.0
# 4  110300030.0    1936          ...   1266.5001    318.0        0.0    5.0
#
# ...

# %%
by_pricing_status= condemns.groupby(['Precinct02', 'Status'])['AcctNum'].count().reset_index()

# %%
by_pricing_status= condemns.groupby(['Precinct02','Status'])['AcctNum'].count().reset_index()

# %%
by_pricing_status

# %%
by_pricing_status.pivot(index='Precinct02', columns='Status', values='AcctNum').fillna(0)

# %%
by_precinct= condemns.pivot_table(index= 'Precinct02',
                                  columns='Status',
                                  values= 'AcctNum',
                                  aggfunc= 'count',
                                  fill_value=0)

# %%
by_precinct
# Out:
# Status         B    L   R     W
# Precinct02
# 1.0          787  413   6   623
# 2.0          886  409   7   727
# 3.0          698  343   6   667
# 4.0          962  469  15   928
# 5.0          788  418  11   635
# 6.0          857  435  10   603
# 7.0          900  454   7   672
# 8.0         1033  453  10  1134
# 9.0          795  354   5   616
# 10.0         917  430   7   811
# 11.0         785  337  15   933
# 12.0         655  247   6   758
# 13.0         419  172   4   597
# 14.0          78   31   1    38
# 15.0          15   19   0    18
# 16.0           6   12   0     4
# 17.0           5    1   0     3
# 98.0           0    0   0     1
# 99.0           0    0   0     1

# %%
by_date= condemns.pivot_table(index= 'Inspect_Date',
                              fill_value=0,
                              columns= 'Status',
                              values= 'Acctnum',
                              agg_func= 'count'
                              )

# %%
#wide to long format Stack
import pandas as pd
flu= pd.read_csv('https://hds5210-data.s3.amazonaws.com/flu_2016_2017.csv')

# %%
flu.head()
# Out:
#        Country                            WHOREGION      FLUREGION  Year  \
# 0  Afghanistan  Eastern Mediterranean Region of WHO  Southern Asia  2016
# 1  Afghanistan  Eastern Mediterranean Region of WHO  Southern Asia  2016
# 2  Afghanistan  Eastern Mediterranean Region of WHO  Southern Asia  2016
# 3  Afghanistan  Eastern Mediterranean Region of WHO  Southern Asia  2016
# 4  Afghanistan  Eastern Mediterranean Region of WHO  Southern Asia  2016
#
#    Week       SDATE       EDATE  SPEC_RECEIVED_NB  SPEC_PROCESSED_NB  AH1  \
# 0     1  2016-01-04  2016-01-10              87.0               87.0  0.0
# 1     2  2016-01-11  2016-01-17              70.0               70.0  0.0
# 2     3  2016-01-18  2016-01-24             102.0              102.0  0.0
# 3     4  2016-01-25  2016-01-31              77.0               77.0  0.0
# 4     5  2016-02-01  2016-02-07              98.0                0.0  0.0
#
#    ...  AH5  ANOTSUBTYPED  INF_A  BYAMAGATA  BVICTORIA  BNOTDETERMINED  INF_B  \
# ...

# %%
stacked= pd.DataFrame(flu.set_index(['Country','WHOREGION','FLUREGION','Year','Week','SDATE','EDATE','TITLE']).stack().reset_index(name='count'))

# %%
stacked
# Out:
#            Country                            WHOREGION       FLUREGION  Year  \
# 0      Afghanistan  Eastern Mediterranean Region of WHO   Southern Asia  2016
# 1      Afghanistan  Eastern Mediterranean Region of WHO   Southern Asia  2016
# 2      Afghanistan  Eastern Mediterranean Region of WHO   Southern Asia  2016
# 3      Afghanistan  Eastern Mediterranean Region of WHO   Southern Asia  2016
# 4      Afghanistan  Eastern Mediterranean Region of WHO   Southern Asia  2016
# ...            ...                                  ...             ...   ...
# 97515       Zambia                African Region of WHO  Eastern Africa  2017
# 97516       Zambia                African Region of WHO  Eastern Africa  2017
# 97517       Zambia                African Region of WHO  Eastern Africa  2017
# 97518       Zambia                African Region of WHO  Eastern Africa  2017
# 97519       Zambia                African Region of WHO  Eastern Africa  2017
#
# ...

# %%
median_temp = [
    ['OK',63,63,64,65,98],
    ['MO',65,64,66,67,100],
    ['KS',64,66,65,65,102]
]

data = pd.DataFrame(median_temp, columns=['Name','2015','2016','2017','2018','2019'])

# %%
data
# Out:
#   Name  2015  2016  2017  2018  2019
# 0   OK    63    63    64    65    98
# 1   MO    65    64    66    67   100
# 2   KS    64    66    65    65   102

# %%
data.melt(id_vars=['name '],
          value_vars= data.columns[1:],
          var_name='Year',
          value_name='Temp')

# %%
median_temp = [
    ['OK',63,63,64,65,68,70,True],
    ['MO',65,64,66,67,69,71,False],
    ['KS',64,66,65,65,72,75,True]
]

data = pd.DataFrame(median_temp, columns=['Name','2015','2016','2017','2018','2019','2020','Flag'])

# %%
data
# Out:
#   Name  2015  2016  2017  2018  2019  2020   Flag
# 0   OK    63    63    64    65    68    70   True
# 1   MO    65    64    66    67    69    71  False
# 2   KS    64    66    65    65    72    75   True

# %%
id_vars= [x for x in data.columns if x[:2] != '20']
id_vars
# Out:
# ['Name', 'Flag']

# %%
value_vars = [x for x in data.columns if x not in id_vars]
value_vars
# Out:
# ['2015', '2016', '2017', '2018', '2019', '2020']

# %%
value_vars= [x for x in data.columns if x not in id_vars]
value_vars

# %%
data.melt(id_vars=id_vars,
          value_vars=value_vars,
          var_name='Year',
          value_name='Temp')
# Out:
#    Name   Flag  Year  Temp
# 0    OK   True  2015    63
# 1    MO  False  2015    65
# 2    KS   True  2015    64
# 3    OK   True  2016    63
# 4    MO  False  2016    64
# 5    KS   True  2016    66
# 6    OK   True  2017    64
# 7    MO  False  2017    66
# 8    KS   True  2017    65
# 9    OK   True  2018    65
# 10   MO  False  2018    67
# 11   KS   True  2018    65
# 12   OK   True  2019    68
# 13   MO  False  2019    69
# 14   KS   True  2019    72
# 15   OK   True  2020    70
# 16   MO  False  2020    71
# 17   KS   True  2020    75

# %% [markdown]
# <a href="https://colab.research.google.com/github/SRARNAB7/HDS_5230_07_Arnab/blob/main/Week_05_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import dask.dataframe as dd

# Define the expected dtypes, including the 'city' column as 'object'
dtypes = {
    'name': 'object',
    'level': 'object',
    'city': 'object',
    'county': 'object',
    'state': 'object',
    'country': 'object',
    'population': 'float64',
    'lat': 'float64',
    'long': 'float64',
    'url': 'object',
    'aggregate': 'object',
    'tz': 'object',
    'cases': 'float64',
    'deaths': 'float64',
    'recovered': 'float64',
    'active': 'float64',
    'tested': 'float64',
    'hospitalized': 'float64',
    'hospitalized_current': 'float64',
    'discharged': 'float64',
    'icu': 'float64',
    'icu_current': 'float64',
    'growthFactor': 'float64'
}

# Load the CSV file into a Dask dataframe with specified dtypes
df_dask = dd.read_csv('timeseries.csv', dtype=dtypes)

# Display the first few rows
df_dask.head()
# Out:
#                          name   level  city   county     state  country  \
# 0  Antwerp, Flanders, Belgium  county  <NA>  Antwerp  Flanders  Belgium
# 1  Antwerp, Flanders, Belgium  county  <NA>  Antwerp  Flanders  Belgium
# 2  Antwerp, Flanders, Belgium  county  <NA>  Antwerp  Flanders  Belgium
# 3  Antwerp, Flanders, Belgium  county  <NA>  Antwerp  Flanders  Belgium
# 4  Antwerp, Flanders, Belgium  county  <NA>  Antwerp  Flanders  Belgium
#
#    population      lat    long                          url  ... recovered  \
# 0   1847486.0  51.2485  4.7175  https://epistat.wiv-isp.be/  ...       NaN
# 1   1847486.0  51.2485  4.7175  https://epistat.wiv-isp.be/  ...       NaN
# 2   1847486.0  51.2485  4.7175  https://epistat.wiv-isp.be/  ...       NaN
# 3   1847486.0  51.2485  4.7175  https://epistat.wiv-isp.be/  ...       NaN
# 4   1847486.0  51.2485  4.7175  https://epistat.wiv-isp.be/  ...       NaN
#
#   active  tested  hospitalized  hospitalized_current  discharged  icu  \
# ...

# %%
# Filter the Dask dataframe to include rows where the 'country' is the United States
df_us = df_dask[df_dask['country'] == 'United States']

# Display the first few rows of the filtered dataframe
df_us.head()
